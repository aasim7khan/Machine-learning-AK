# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.sparse import csr_matrix

# %%
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC

# %%
movies = pd.read_csv('D:/CSR_MATRIX/test.csv')
movies.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
movies.head()

# %%
movies.shape

# %%
movies.describe().transpose()
# Out:
#                 count         mean          std     min      25%     50%  \
# Id             1459.0  2190.000000   421.321334  1461.0  1825.50  2190.0
# MSSubClass     1459.0    57.378341    42.746880    20.0    20.00    50.0
# LotFrontage    1232.0    68.580357    22.376841    21.0    58.00    67.0
# LotArea        1459.0  9819.161069  4955.517327  1470.0  7391.00  9399.0
# OverallQual    1459.0     6.078821     1.436812     1.0     5.00     6.0
# OverallCond    1459.0     5.553804     1.113740     1.0     5.00     5.0
# YearBuilt      1459.0  1971.357779    30.390071  1879.0  1953.00  1973.0
# YearRemodAdd   1459.0  1983.662783    21.130467  1950.0  1963.00  1992.0
# MasVnrArea     1444.0   100.709141   177.625900     0.0     0.00     0.0
# BsmtFinSF1     1458.0   439.203704   455.268042     0.0     0.00   350.5
# BsmtFinSF2     1458.0    52.619342   176.753926     0.0     0.00     0.0
# BsmtUnfSF      1458.0   554.294925   437.260486     0.0   219.25   460.0
# ...

# %%
ratings = pd.read_csv('D:/CSR_MATRIX/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
ratings.shape

# %%
ratings.describe().transpose()

# %%
movies.head()

# %%
movies.tail()

# %%
ratings.head()

# %%
ratings.groupby('movieId').rating.mean()
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
df=movies.join(ratings,lsuffix='N', rsuffix='K')
df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold SaleType  \
# 0         Lvl    AllPub  ...         NaN       0      6   2010       WD
# 1         Lvl    AllPub  ...        Gar2   12500      6   2010       WD
# 2         Lvl    AllPub  ...         NaN       0      3   2010       WD
# 3         Lvl    AllPub  ...         NaN       0      6   2010       WD
# 4         HLS    AllPub  ...         NaN       0      1   2010       WD
#
#   SaleCondition userId  movieId  rating   timestamp
# ...

# %%
df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold SaleType  \
# 0         Lvl    AllPub  ...         NaN       0      6   2010       WD
# 1         Lvl    AllPub  ...        Gar2   12500      6   2010       WD
# 2         Lvl    AllPub  ...         NaN       0      3   2010       WD
# 3         Lvl    AllPub  ...         NaN       0      6   2010       WD
# 4         HLS    AllPub  ...         NaN       0      1   2010       WD
#
#   SaleCondition userId  movieId  rating   timestamp
# ...

# %%
'''df=df.drop(['genres','movie_info','critics_consensus','content_rating','directors','authors','actors','original_release_date'], axis=1)
df.head()'''
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2096\3537935890.py in <module>
# ----> 1 df=df.drop(['genres','movie_info','critics_consensus','content_rating','directors','authors','actors','original_release_date'], axis=1)
#       2 df.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
movies_user=df.pivot(index='movieId',columns='userId',values='rating').fillna=0
matrix_movies_user=csr_matrix(movies_user.values)
print(matrix_movies_user)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2096\646679722.py in <module>
#       1 movies_user=df.pivot(index='movieId',columns='userId',values='rating').fillna=0
# ----> 2 matrix_movies_user=csr_matrix(movies_user.values)
#       3 print(matrix_movies_user)
#
# AttributeError: 'int' object has no attribute 'values'

# %%
knn=NearestNeighbours(metric='cosine', algorithm='brute',n_neighbours= 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2096\2475727636.py in <module>
# ----> 1 knn=NearestNeighbours(metric='cosine', algorithm='brute',n_neighbours= 10)
#
# NameError: name 'NearestNeighbours' is not defined

# %%
knn.fit(matrix_movies_user)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2096\3400962950.py in <module>
# ----> 1 knn.fit(matrix_movies_user)
#
# NameError: name 'knn' is not defined

# %%
def recommender(movie_name,data, model, n_recommendation):
    model.fit(data)
    idx=process.extractOne(movie_name, df['title'])[2]
    print('Movie Selected:- ',df['title'][idx], 'Index: ',idx)
    print('Searching for recommendations....')
    distances, indices=model.kneighbours(data[idx],n_neighbours= n_recommendation)
    for i in indices:
        print(df['title'][i].where(i=idx))

# %%
recommender('Bad Poems',matrix_movies_user, knn,5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2096\1204274887.py in <module>
# ----> 1 recommender('Bad Poems',matrix_movies_user, knn,5)
#
# NameError: name 'matrix_movies_user' is not defined
